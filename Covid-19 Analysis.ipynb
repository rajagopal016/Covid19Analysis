# %%
import pandas as pd
import matplotlib.pyplot as plt
covid_data= pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv')

# %% [markdown]
# 1. Write a Python program to display first 5 rows from COVID-19 dataset. Also print the dataset information and check the missing values.

# %%
df1=covid_data.head(5)
df1
# Out:
#   Province/State Country/Region          Last Update  Confirmed  Deaths  \
# 0          Hubei          China  2020-03-17T11:53:10      67799    3111
# 1            NaN          Italy  2020-03-17T18:33:02      31506    2503
# 2            NaN           Iran  2020-03-17T15:13:09      16169     988
# 3            NaN          Spain  2020-03-17T20:53:02      11748     533
# 4            NaN        Germany  2020-03-17T18:53:02       9257      24
#
#    Recovered  Latitude  Longitude
# 0      56003   30.9756   112.2707
# 1       2941   41.8719    12.5674
# 2       5389   32.4279    53.6880
# 3       1028   40.4637    -3.7492
# 4         67   51.1657    10.4515

# %% [markdown]
# 2. Write a Python program to get the latest number of confirmed, deaths, recovered and active cases of Novel Coronavirus (COVID-19) Country wise.

# %%
df2 = covid_data[['Country/Region', 'Confirmed', 'Deaths', 'Recovered']]
df2['Active'] = df2['Confirmed'] - (df2['Deaths'] + df2['Recovered'])
print(df2)
# Out:
#                        Country/Region  Confirmed  Deaths  Recovered  Active
# 0                               China      67799    3111      56003    8685
# 1                               Italy      31506    2503       2941   26062
# 2                                Iran      16169     988       5389    9792
# 3                               Spain      11748     533       1028   10187
# 4                             Germany       9257      24         67    9166
# 5                        Korea, South       8320      81       1407    6832
# 6                              France       7652     148         12    7492
# 7                         Switzerland       2700      27          4    2669
# 8                      United Kingdom       1950      55         52    1843
# 9                                  US       1706      13          0    1693
# 10                        Netherlands       1705      43          2    1660
# ...

# %% [markdown]
# 3. Write a Python program to get the latest number of confirmed deaths and recovered people of Novel Coronavirus (COVID-19) cases Country/Region - Province/State wise.

# %%
df3 = covid_data.groupby(['Country/Region', 'Province/State'])['Confirmed', 'Deaths', 'Recovered'].max()
pd.set_option('display.max_rows', None)
print(df3)
# Out:
#                                              Confirmed  Deaths  Recovered
# Country/Region Province/State
# Australia      Australian Capital Territory          2       0          0
#                From Diamond Princess                 0       0          0
#                New South Wales                     210       4          4
#                Northern Territory                    1       0          0
#                Queensland                           78       0          8
#                South Australia                      29       0          3
#                Tasmania                              7       0          0
#                Victoria                             94       0          8
#                Western Australia                    31       1          0
# Canada         Alberta                              74       0          0
#                British Columbia                    103       4          4
# ...

# %% [markdown]
# 4. Write a Python program to get the Chinese province wise cases of confirmed, deaths and recovered cases of Novel Coronavirus (COVID-19).

# %%
df4=covid_data
df4 = (df4[df4["Country/Region"] == 'China'])[['Province/State','Confirmed', 'Deaths', 'Recovered']]
df4=df4.sort_values(by=['Province/State'])
df4.reset_index(drop=True)
# Out:
#     Province/State  Confirmed  Deaths  Recovered
# 0            Anhui        990       6        984
# 1          Beijing        456       8        369
# 2        Chongqing        576       6        570
# 3           Fujian        296       1        295
# 4            Gansu        133       2         91
# 5        Guangdong       1364       8       1307
# 6          Guangxi        253       2        248
# 7          Guizhou        147       2        144
# 8           Hainan        168       6        161
# 9            Hebei        318       6        310
# 10    Heilongjiang        482      13        456
# 11           Henan       1273      22       1250
# 12       Hong Kong        162       4         88
# 13           Hubei      67799    3111      56003
# 14           Hunan       1018       4       1014
# 15  Inner Mongolia         75       1         73
# 16         Jiangsu        631       0        631
# 17         Jiangxi        935       1        934
# ...

# %% [markdown]
# 5. Write a Python program to get the latest country wise deaths cases of Novel Coronavirus (COVID-19).

# %%
df5 = covid_data
df5 = df5.groupby(['Country/Region'])['Deaths'].sum()
df5
# Out:
# Country/Region
# Afghanistan                            0
# Albania                                1
# Algeria                                4
# Andorra                                0
# Antigua and Barbuda                    0
# Argentina                              2
# Armenia                                0
# Aruba                                  0
# Australia                              5
# Austria                                3
# Azerbaijan                             1
# Bahrain                                1
# Bangladesh                             0
# Barbados                               0
# Belarus                                0
# Belgium                               10
# Benin                                  0
# Bhutan                                 0
# Bolivia                                0
# Bosnia and Herzegovina                 0
# Brazil                                 1
# Brunei                                 0
# ...

# %% [markdown]
# 6. Write a Python program to list countries with no cases of Novel Coronavirus (COVID-19) recovered.

# %%
df6 = covid_data
df6 =  df6.groupby(['Country/Region'])['Confirmed', 'Deaths', 'Recovered'].sum()
df6[df6['Recovered'] == 0]
# Out:
# C:\Users\RKrishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                                   Confirmed  Deaths  Recovered
# Country/Region
# Albania                                  55       1          0
# Antigua and Barbuda                       1       0          0
# Aruba                                     3       0          0
# Barbados                                  2       0          0
# Benin                                     1       0          0
# Bhutan                                    1       0          0
# Bolivia                                  11       0          0
# Brunei                                   56       0          0
# Bulgaria                                 67       2          0
# Burkina Faso                             15       0          0
# Cameroon                                 10       0          0
# ...

# %% [markdown]
# 7. Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) died.

# %%
df7 = covid_data
df7 =  df7.groupby(['Country/Region'])['Confirmed', 'Deaths', 'Recovered'].sum()
df7 = df7[df7['Confirmed'] > 0]
df7[df7['Deaths'] == df7['Confirmed']]
# Out:
# C:\Users\RKrishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                 Confirmed  Deaths  Recovered
# Country/Region
# Sudan                   1       1          0

# %% [markdown]
# 8. Write a Python program to list countries with all cases of Novel Coronavirus (COVID-19) recovered.

# %%
df8 = covid_data
df8=df8.groupby(['Country/Region'])['Confirmed','Deaths','Recovered'].sum()
df8=df8[df8['Confirmed'] > 0]
df8=df8[df8['Recovered'] == df8['Confirmed']]
df8
# Out:
# C:\Users\RKrishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#                 Confirmed  Deaths  Recovered
# Country/Region
# Nepal                   1       0          1

# %% [markdown]
# 9. Write a Python program to get the top 10 countries data (Last Update, Country/Region, Confirmed, Deaths, Recovered) of Novel Coronavirus (COVID-19).

# %%
df9 = covid_data
df9 = df9[['Country/Region', 'Last Update', 'Confirmed', 'Deaths', 'Recovered']].sort_values(by='Confirmed',ascending=False)
df9.head(10)
# Out:
#    Country/Region          Last Update  Confirmed  Deaths  Recovered
# 0           China  2020-03-17T11:53:10      67799    3111      56003
# 1           Italy  2020-03-17T18:33:02      31506    2503       2941
# 2            Iran  2020-03-17T15:13:09      16169     988       5389
# 3           Spain  2020-03-17T20:53:02      11748     533       1028
# 4         Germany  2020-03-17T18:53:02       9257      24         67
# 5    Korea, South  2020-03-17T10:33:03       8320      81       1407
# 6          France  2020-03-17T19:13:08       7652     148         12
# 7     Switzerland  2020-03-17T16:33:04       2700      27          4
# 8  United Kingdom  2020-03-17T15:13:09       1950      55         52
# 9              US  2020-03-17T22:53:03       1706      13          0

# %% [markdown]
# 10. Write a Python program to create a plot (lines) of total deaths, confirmed, recovered and active cases Country wise where deaths greater than 150.

# %%
df10 = covid_data
df10 = df10.groupby(['Country/Region'])['Confirmed','Deaths','Recovered'].sum().reset_index()
df10['Active'] = df10['Confirmed'] - (df10['Deaths'] - df10['Recovered'])
df10=df10[df10['Deaths'] > 150]
df10
plt.figure(figsize=(15, 5))
plt.plot(df10['Country/Region'], df10['Deaths'], color='red')
plt.plot(df10['Country/Region'], df10['Confirmed'], color='Blue')
plt.plot(df10['Country/Region'], df10['Recovered'], color='Green')
plt.plot(df10['Country/Region'], df10['Active'], color='Yellow')

plt.title('Total Deaths(>150), Confirmed, Recovered and Active Cases by Country')
plt.show()
# Out:
# C:\Users\RKrishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.

# %% [markdown]
# 11. Write a Python program to visualize the state/province wise death cases of Novel Coronavirus (COVID-19) in USA.

# %%
df11 = covid_data
df11 = df11[df11['Country/Region'] == 'US'].reset_index(drop=1)
df11 = df11[df11['Deaths'] > 0]

fig = plt.figure(figsize=(20,10))
ax = fig.add_axes([0,0,1,1])
ax.bar(df11['Province/State'],df11['Deaths'])
ax.set_xticklabels(df11['Province/State'], rotation=90, ha='right')
plt.title("State/Province wise death cases of Novel Coronavirus (COVID-19) in USA", fontsize=20 )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-454-f23aa3eddf09> in <module>
#       5 fig = plt.figure(figsize=(20,10))
#       6 ax = fig.add_axes([0,0,1,1])
# ----> 7 ax.bar(df11['Deaths'])
#       8 ax.set_xticklabels(df11['Province/State'], rotation=90, ha='right')
#       9 plt.title("State/Province wise death cases of Novel Coronavirus (COVID-19) in USA", fontsize=20 )
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %% [markdown]
# 12. Write a Python program to visualize the state/province wise Active cases of Novel Coronavirus (COVID-19) in USA

# %%
df12 = covid_data
df12["Active"] = df12["Confirmed"] - df12["Recovered"] - df12['Deaths']
df12 = df12[df12["Country/Region"] == "US"].reset_index()
df12 = df12.groupby(["Province/State"])["Province/State","Confirmed", "Active", "Deaths", "Recovered"].sum().reset_index()
df12 = df12[df12["Active"] > 0]
#df12
#plt.plot(  )
plt.xticks(df12['Active'], df12["Province/State"], rotation='vertical')
plt
fig = plt.figure(figsize=(30,10))

ax = fig.add_axes([0,0,1,1])
ax.bar(df12['Province/State'],df12['Active'])
plt.title("State/Province wise Active cases of Novel Coronavirus (COVID-19) in USA", fontsize=20 )
# Out:
# C:\Users\RKrishna\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'State/Province wise Active cases of Novel Coronavirus (COVID-19) in USA')

# %% [markdown]
# 13. Write a Python program to visualize Worldwide Confirmed Novel Coronavirus (COVID-19) cases over time.

# %%
df13 = covid_data 
df13  = df13.groupby(["Last Update"])["Last Update", "Confirmed"].sum().reset_index()
df13
plt.figure(figsize=(25, 5))
plt.plot(df13["Last Update"], df13["Confirmed"])
plt.xticks(rotation=90)
plt.title("Worldwide Confirmed Novel Coronavirus (COVID-19) cases over time", fontsize=20)
plt.show()
